# %%
# !pip install unetseg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: unetseg in /usr/local/lib/python3.8/dist-packages (0.2.2)
# Requirement already satisfied: attrs<21.3,>=21.2.0 in /usr/local/lib/python3.8/dist-packages (from unetseg) (21.2.0)
# Requirement already satisfied: rasterio<1.3,>=1.2 in /usr/local/lib/python3.8/dist-packages (from unetseg) (1.2.10)
# Requirement already satisfied: scikit-image<0.19,>=0.18.3 in /usr/local/lib/python3.8/dist-packages (from unetseg) (0.18.3)
# Requirement already satisfied: tifffile>=2021.11.2 in /usr/local/lib/python3.8/dist-packages (from unetseg) (2022.10.10)
# Requirement already satisfied: scikit-learn<1.1,>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from unetseg) (1.0.2)
# Requirement already satisfied: matplotlib<3.6,>=3.5.0 in /usr/local/lib/python3.8/dist-packages (from unetseg) (3.5.3)
# Requirement already satisfied: opencv-python>=4.5 in /usr/local/lib/python3.8/dist-packages (from unetseg) (4.6.0.66)
# Requirement already satisfied: albumentations<1.2,>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from unetseg) (1.1.0)
# Requirement already satisfied: tqdm>=4.62.3 in /usr/local/lib/python3.8/dist-packages (from unetseg) (4.64.1)
# Requirement already satisfied: tensorflow>=2.4 in /usr/local/lib/python3.8/dist-packages (from unetseg) (2.9.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from albumentations<1.2,>=1.1.0->unetseg) (6.0)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.8/dist-packages (from albumentations<1.2,>=1.1.0->unetseg) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from albumentations<1.2,>=1.1.0->unetseg) (1.7.3)
# Requirement already satisfied: qudida>=0.0.4 in /usr/local/lib/python3.8/dist-packages (from albumentations<1.2,>=1.1.0->unetseg) (0.0.4)
# Requirement already satisfied: opencv-python-headless>=4.1.1 in /usr/local/lib/python3.8/dist-packages (from albumentations<1.2,>=1.1.0->unetseg) (4.7.0.68)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib<3.6,>=3.5.0->unetseg) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib<3.6,>=3.5.0->unetseg) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib<3.6,>=3.5.0->unetseg) (21.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib<3.6,>=3.5.0->unetseg) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib<3.6,>=3.5.0->unetseg) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib<3.6,>=3.5.0->unetseg) (7.1.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib<3.6,>=3.5.0->unetseg) (1.4.4)
# Requirement already satisfied: snuggs>=1.4.1 in /usr/local/lib/python3.8/dist-packages (from rasterio<1.3,>=1.2->unetseg) (1.4.7)
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from rasterio<1.3,>=1.2->unetseg) (2022.12.7)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.8/dist-packages (from rasterio<1.3,>=1.2->unetseg) (7.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from rasterio<1.3,>=1.2->unetseg) (57.4.0)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.8/dist-packages (from rasterio<1.3,>=1.2->unetseg) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.8/dist-packages (from rasterio<1.3,>=1.2->unetseg) (0.7.2)
# Requirement already satisfied: affine in /usr/local/lib/python3.8/dist-packages (from rasterio<1.3,>=1.2->unetseg) (2.3.1)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image<0.19,>=0.18.3->unetseg) (2.9.0)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from scikit-image<0.19,>=0.18.3->unetseg) (1.4.1)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.8/dist-packages (from scikit-image<0.19,>=0.18.3->unetseg) (3.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn<1.1,>=1.0.1->unetseg) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn<1.1,>=1.0.1->unetseg) (3.1.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.4->unetseg) (1.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.4->unetseg) (1.6.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.4->unetseg) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.4->unetseg) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.4->unetseg) (1.51.1)
# Requirement already satisfied: tensorboard<2.10,>=2.9 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.4->unetseg) (2.9.1)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.4->unetseg) (4.4.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.4->unetseg) (3.19.6)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.4->unetseg) (3.1.0)
# Requirement already satisfied: flatbuffers<2,>=1.12 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.4->unetseg) (1.12)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.4->unetseg) (1.14.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.4->unetseg) (1.1.2)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.4->unetseg) (0.4.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.4->unetseg) (14.0.6)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.4->unetseg) (2.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.4->unetseg) (0.29.0)
# Requirement already satisfied: tensorflow-estimator<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.4->unetseg) (2.9.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.4->unetseg) (1.15.0)
# Requirement already satisfied: keras<2.10.0,>=2.9.0rc0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.4->unetseg) (2.9.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow>=2.4->unetseg) (0.38.4)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.4->unetseg) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.4->unetseg) (2.25.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.4->unetseg) (2.15.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.4->unetseg) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.4->unetseg) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.4->unetseg) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.10,>=2.9->tensorflow>=2.4->unetseg) (3.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.4->unetseg) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.4->unetseg) (5.2.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.4->unetseg) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.4->unetseg) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=2.4->unetseg) (6.0.0)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.4->unetseg) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.4->unetseg) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.10,>=2.9->tensorflow>=2.4->unetseg) (2.10)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.10,>=2.9->tensorflow>=2.4->unetseg) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.10,>=2.9->tensorflow>=2.4->unetseg) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.10,>=2.9->tensorflow>=2.4->unetseg) (3.2.2)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: gdown in /usr/local/lib/python3.8/dist-packages (4.4.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.8/dist-packages (from gdown) (2.25.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.8/dist-packages (from gdown) (3.9.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from gdown) (1.15.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from gdown) (4.64.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.8/dist-packages (from gdown) (4.6.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (2022.12.7)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.8/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
## Entrenamiento

# %%
from unetseg.train import TrainConfig, train
from unetseg.evaluate import plot_data_generator
import os

# %%
# !ls /content/drive/MyDrive/Basurales/AMBA/labels/
# Out:
# ANOTACIONES  CHIPS  info.gdoc  poligonos  puntos

# %%
# Movemos a carpeta local para acelerar el entrenamiento
# !cp -r $chips_folder /tmp/
# Out:
# Retrieving folder list
# Retrieving folder 10FIDxqDobbxrg70pPz44Nun9QjyOaxFB extent
# Processing file 1MXM2ay7tzw87emt0OaLfwY1eVBl0nIQG 2016-NOV-MOSAIC-SENTINEL_RGB_236_109.tif
# Processing file 1NONFU-2cwqQ7oWl207J507-OMQ-Ls4Az 2016-NOV-MOSAIC-SENTINEL_RGB_238_107.tif
# Processing file 1OxCPC59suXj_Z4o5ZcRyZUS3oQS9IL2D 2016-NOV-MOSAIC-SENTINEL_RGB_239_108.tif
# Processing file 1Orc50ksPVgRPfTl-hMIuDfEyURMUlIok 2016-NOV-MOSAIC-SENTINEL_RGB_239_109.tif
# Processing file 1OHbIB1rhAfDt34t-lFbnO4CHj-Z1_nqK 2016-NOV-MOSAIC-SENTINEL_RGB_240_109.tif
# Processing file 1QE67kPbbyDvuvZL4-E1xu0BbrMY9p0h7 2016-NOV-MOSAIC-SENTINEL_RGB_251_110.tif
# Processing file 1Q4o-exeiQOM3B86E2E5lI5qzx1_iNspW 2016-NOV-MOSAIC-SENTINEL_RGB_251_111.tif
# Processing file 1Q1yknPMBMALSbgzJJo3Wnm_zZYpvt8zB 2016-NOV-MOSAIC-SENTINEL_RGB_251_112.tif
# Processing file 1PRfix3mvkGYB-kjDq73H0Ss3QG_yMAfR 2016-NOV-MOSAIC-SENTINEL_RGB_252_111.tif
# Processing file 1R5h5e0f0gJ7MfDSV_jBEQCBcNdgZ1Abp 2016-NOV-MOSAIC-SENTINEL_RGB_253_111.tif
# Processing file 1R0_oj6xxZhwTzSOZGWGEzM3xv3R_S51P 2016-NOV-MOSAIC-SENTINEL_RGB_253_112.tif
# Processing file 1QPY4ID_gnK3QnxUGJKgxXGFmdxk288vK 2016-NOV-MOSAIC-SENTINEL_RGB_254_111.tif
# Processing file 1RL7yIPy-XArkCTcXegfCVg0KjkYIwqTL 2016-NOV-MOSAIC-SENTINEL_RGB_295_126.tif
# Processing file 1THCZPso7a6XTkDxH6loin92RB_Relxnw 2016-NOV-MOSAIC-SENTINEL_RGB_295_127.tif
# Processing file 1T0Mo26O5AQKP51nV4CDTgffLCFrHiubv 2016-NOV-MOSAIC-SENTINEL_RGB_295_128.tif
# Processing file 1SwJ_uIq5kclPrUi7vavXVw6lMyPwiQhR 2016-NOV-MOSAIC-SENTINEL_RGB_296_124.tif
# Processing file 1Sq-VgM4iornHR4jo5mSmHrItosaS2vBR 2016-NOV-MOSAIC-SENTINEL_RGB_296_125.tif
# Processing file 1UVUur9IjWNzy6zrvP2sNJeZhgGIbkhJf 2016-NOV-MOSAIC-SENTINEL_RGB_297_102.tif
# Processing file 1VLcjkKSchjL121xC_cLQ0c0N37XQfnj- 2016-NOV-MOSAIC-SENTINEL_RGB_298_102.tif
# Processing file 1V52tJXOnvCLb1gQkMSlYO5hHmnWjKLDI 2016-NOV-MOSAIC-SENTINEL_RGB_298_104.tif
# Processing file 1WMyaYqNFFRSstnC4eriHEekNDKY1Abos 2016-NOV-MOSAIC-SENTINEL_RGB_299_105.tif
# Processing file 1VjCXDtDGMPYjU_gDvk8SnjX4yvypjy2T 2016-NOV-MOSAIC-SENTINEL_RGB_300_103.tif
# Processing file 1Vc0k9Bw9pVw6nqbVju9mdUUKGmOWHSOG 2016-NOV-MOSAIC-SENTINEL_RGB_300_104.tif
# Processing file 1WwY8ALW5uP6x0KjyFeawboQzIV1JFmHu 2016-NOV-MOSAIC-SENTINEL_RGB_303_98.tif
# Processing file 1Yb3Nv6SIBj2hM2UOcUcGEidJDsQDQQ8Z 2016-NOV-MOSAIC-SENTINEL_RGB_303_101.tif
# Processing file 1YU4wP9jNnmAk5jRc0F7hx9ntRO-oedoQ 2016-NOV-MOSAIC-SENTINEL_RGB_304_98.tif
# Processing file 1ZQzr64g9NBMNRLVXCMkJPmLoKpsnTt9i 2016-NOV-MOSAIC-SENTINEL_RGB_305_100.tif
# Processing file 1ZProMdujEu_2hlqSfuVagIbXLaH-DApy 2016-NOV-MOSAIC-SENTINEL_RGB_305_101.tif
# Processing file 1_5ff2R_N2c6vy6LGKghLAX575O4wSclB 2016-NOV-MOSAIC-SENTINEL_RGB_317_127.tif
# Processing file 1ZpJpaiqHeHlu4MK8hq1uPJCVy1_nDpr2 2016-NOV-MOSAIC-SENTINEL_RGB_318_125.tif
# Processing file 1ZaDjt09bkB1fXV0orhGAVdmZzvFzgePE 2016-NOV-MOSAIC-SENTINEL_RGB_318_126.tif
# Processing file 1ZUigARE81BiK9agBoDzZQMHzlP-gVIUS 2016-NOV-MOSAIC-SENTINEL_RGB_319_124.tif
# Processing file 1_fFPz4Cek6wyoM1SvR-zbJfpsjCj9AEb 2016-NOV-MOSAIC-SENTINEL_RGB_327_135.tif
# Processing file 1_N6ao2UJbvSF21oI7GhiVOnYfl8rS1CZ 2016-NOV-MOSAIC-SENTINEL_RGB_327_137.tif
# Processing file 1abgiybWu1IyN268XWPii_s-qTY4_Ogvl 2016-NOV-MOSAIC-SENTINEL_RGB_328_135.tif
# Processing file 1aZctknNBN5nFdhIXB7ThBdpZzjrnAlq_ 2016-NOV-MOSAIC-SENTINEL_RGB_328_136.tif
# Processing file 1aPmpVmud7UrDwvxJW8sQz7HkfPONYNqY 2016-NOV-MOSAIC-SENTINEL_RGB_328_138.tif
# Processing file 1b5nHGyZCVTEU_LFfXSlrEvDFVagTyA9q 2016-NOV-MOSAIC-SENTINEL_RGB_330_138.tif
# Processing file 12KbdnR4UApqt0cCFX0fQDEQ0mxrgi7NA 2017-DIC-MOSAIC-SENTINEL_RGB_214_87.tif
# Processing file 11mCBkzKSC0rLGJP33vyv9g8qOOgyLbrz 2017-DIC-MOSAIC-SENTINEL_RGB_214_89.tif
# Processing file 14pPVjcNzfq4rBe48KJcxlillaESQlsWu 2017-DIC-MOSAIC-SENTINEL_RGB_216_88.tif
# Processing file 14XbehRtNr1LOgQBB87sYYSh-MhDINH1F 2017-DIC-MOSAIC-SENTINEL_RGB_216_90.tif
# Processing file 14MU7UJZ6ccm9ERBZ6xDyqqFGZc6ygUw4 2017-DIC-MOSAIC-SENTINEL_RGB_224_103.tif
# Processing file 141yqjNOLV2ZXdiRQjBnwBh7M0QLH76bD 2017-DIC-MOSAIC-SENTINEL_RGB_224_105.tif
# Processing file 15FgkkspQLq1IObAvfvC4NGcPQioAuJXL 2017-DIC-MOSAIC-SENTINEL_RGB_227_104.tif
# Processing file 16remjLgKPVB88-a-nB4WEwpCrc5xFgKR 2017-DIC-MOSAIC-SENTINEL_RGB_255_107.tif
# Processing file 16JuQUasplolGd4EGA9UTBDA5lB-qXIbt 2017-DIC-MOSAIC-SENTINEL_RGB_256_108.tif
# Processing file 17i6RT2ZxrC-30pVo1Z3DbgA1OjmjvGnN 2017-DIC-MOSAIC-SENTINEL_RGB_256_110.tif
# Processing file 17HfAImXU3oZNRjbdiYcSl35M4WHG3rZP 2017-DIC-MOSAIC-SENTINEL_RGB_257_109.tif
# Processing file 174hr-Td7w5q75koR3gAZfvqHHgWamldW 2017-DIC-MOSAIC-SENTINEL_RGB_258_67.tif
# Failed to retrieve folder contents:
#
#  	The gdrive folder with url: https://drive.google.com/drive/folders/10F
# 	IDxqDobbxrg70pPz44Nun9QjyOaxFB has at least 50 files, gdrive can't
# 	download more than this limit, if you are ok with this, please run
# 	again with --remaining-ok flag.

# %%
local_chips_folder = "/tmp/CHIPS/"

# %%
# Cuantas imágenes para entrenar ("chips") tenemos?
# !ls $local_chips_folder/images/ | wc -l
# Out:
# 7476

# %%
# Aqui va la cantidad de imágenes / chips disponibles
n_img = 14209

# batch size: cantidad de datos que se procesan por vez, puede ser limitado por 
# la memoria de gpu disponible 
batch = 96

# steps per epoch: típicamente debe ser igual al numero de imágenes / el batch_size 
# (con un 10% arriba esta bien), si es mayor incrementara el número de imágenes 
# generadas con image augmentation
steps = round((n_img / batch ) * 1.1)

# tamaño de la imagen procesada por la UNet (debe ser multiplos de 16 , por ej 160, 320, etc) y lo mas parecida posible a la resolucion de los chips
unet_input_size = 160

# donde guardar el modelo (ruta y nombre de archivo) // guardamos en drive para preservarlo si se apaga la instancia de colab
model_file = '/content/drive/MyDrive/Basurales/AMBA/models/2023_01_chipsize_160_48.h5'

config = TrainConfig(width=unet_input_size, 
                     height=unet_input_size,
                     n_channels=3,  #  número de canales de la imagen, rgb -> 3
                     n_classes=1, # número de clases a clasificar
                     apply_image_augmentation=True, #  si es True , amplia el dataset generando imagenes nuevas a partir de pequeñas variaciones de las ya existentes 
                     seed=42,
                     epochs=300, # Cantidad de veces que el dataset entero puede pasar por el proceso de entrenamiento
                     batch_size=batch, 
                     steps_per_epoch=steps, 
                     early_stopping_patience=20, # a medida que entrena se guarda los resultados del entrenamiento despues de cada epoch, si el error no varió luego de N iteraciones , se corta el proceso porque se entiende que el error ya disminuyó significativamente 
                     validation_split=0.2, # se divide la muestra en training y validation para calcular el error durante el proceso de entrenamiento
                     test_split=0.1,
                     images_path=local_chips_folder, #ruta a las imágenes
                     model_path=model_file, # ruta donde guardar el modelo entrenado
                     model_architecture='unet',
                     class_weights = [1],
                     evaluate=True) 

# con clases desbalanceadas se puede agregar el parámetro class_weights para darle mas peso a las clases minoritarias
# p.e.  class_weights = [0.8, 0.2]

# %%
plot_data_generator(num_samples=5, fig_size=(10, 10), train_config=config, img_ch = 3)
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# rasterio/_shim.pyx in rasterio._shim.open_dataset()
#
# rasterio/_err.pyx in rasterio._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: /tmp/CHIPS/extent/2017-NOV-MOSAIC-SENTINEL_RGB_BIS_425_206.tif: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# RasterioIOError                           Traceback (most recent call last)
# <ipython-input-13-5b87370dd183> in <module>
# ----> 1 plot_data_generator(num_samples=5, fig_size=(10, 10), train_config=config, img_ch = 3)
#
# /usr/local/lib/python3.8/dist-packages/unetseg/evaluate.py in plot_data_generator(num_samples, fig_size, train_config, img_ch)
#      72                     return
#      73
# ---> 74     plot_samples(plt, data_generator, num_samples)
#      75     plt.show()
#      76
#
# /usr/local/lib/python3.8/dist-packages/unetseg/evaluate.py in plot_samples(plt, generator, num)
#      54     def plot_samples(plt, generator, num):
#      55         j = 0
# ---> 56         for image_batch, mask_batch in data_generator:
#      57             for image, mask in zip(image_batch, mask_batch):
#      58                 _, ax = plt.subplots(
#
# /usr/local/lib/python3.8/dist-packages/unetseg/train.py in build_data_generator(image_files, config, mask_dir)
#     553         for input_path in batch_paths:
#     554             input = get_raster(input_path, n_channels=config.n_channels)
# --> 555             mask = get_mask_raster(
#     556                 input_path, mask_dir=mask_dir, n_channels=config.n_classes
#     557             )
#
# /usr/local/lib/python3.8/dist-packages/unetseg/train.py in get_mask_raster(image_path, n_channels, mask_dir)
#     516     basename = os.path.basename(image_path)
#     517     mask_path = os.path.join(mask_dir, basename)
# --> 518     with rasterio.open(mask_path) as src:
#     519         if not n_channels:
#     520             n_channels = src.count
#
# /usr/local/lib/python3.8/dist-packages/rasterio/env.py in wrapper(*args, **kwds)
#     435
#     436         with env_ctor(session=session):
# --> 437             return f(*args, **kwds)
#     438
#     439     return wrapper
#
# /usr/local/lib/python3.8/dist-packages/rasterio/__init__.py in open(fp, mode, driver, width, height, count, crs, transform, dtype, nodata, sharing, **kwargs)
#     218         # None.
#     219         if mode == 'r':
# --> 220             s = DatasetReader(path, driver=driver, sharing=sharing, **kwargs)
#     221         elif mode == "r+":
#     222             s = get_writer_for_path(path, driver=driver)(
#
# rasterio/_base.pyx in rasterio._base.DatasetBase.__init__()
#
# RasterioIOError: /tmp/CHIPS/extent/2017-NOV-MOSAIC-SENTINEL_RGB_BIS_425_206.tif: No such file or directory

# %%
res_config = train(config)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(16,4))

plt.subplot(121)
plt.plot(res_config.history['loss'])
plt.plot(res_config.history['val_loss'])
plt.title('Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')

plt.subplot(122)
plt.plot(res_config.history['mean_io_u_2'])
plt.plot(res_config.history['val_mean_io_u_2'])
plt.title('mean_iou')
plt.ylabel('val_mean_iou')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')


plt.show()
