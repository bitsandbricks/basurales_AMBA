# %%
# !pip install rasterio
# !pip install fiona
# !pip install pysatproc

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pathlib

annotations_dir = '/content/drive/MyDrive/Basurales/AMBA/labels/ANOTACIONES/'
chips_dir = '/tmp/CHIPS/'
chip_size = 160
step_size = 48

# %%
def process_folder(location, output_dir, chip_size, step_size):
    image = location + "/*_RGB*.tif"
    labels = location + "/*.gpkg"

    # !satproc_extract_chips \
        $image \
        -o  $chips_dir \
        --size $chip_size \
        --step-size $step_size \
        --aoi $labels \
        --labels $labels \
        --label-property 'clase' \
        --classes 'basural'

# %%
for location in map(lambda x: x.as_posix(), pathlib.Path(annotations_dir).iterdir()):
    print("Extracting chips from " + location)
    process_folder(location, chips_dir, chip_size, step_size)
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
#
# 2017-NOV-MOSAIC-SENTINEL_RGB_BIS.tif windows:  83% 6076/7286 [01:35<00:16, 73.06it/s]/usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
#
# 2017-NOV-MOSAIC-SENTINEL_RGB_BIS.tif windows:  84% 6085/7286 [01:35<00:15, 76.04it/s]/usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
#
# 2017-NOV-MOSAIC-SENTINEL_RGB_BIS.tif windows:  84% 6095/7286 [01:35<00:14, 80.19it/s]/usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
#
# 2017-NOV-MOSAIC-SENTINEL_RGB_BIS.tif windows:  84% 6104/7286 [01:36<00:14, 78.91it/s]/usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
#
# 2017-NOV-MOSAIC-SENTINEL_RGB_BIS.tif windows:  84% 6112/7286 [01:36<00:15, 77.86it/s]/usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
#
# 2017-NOV-MOSAIC-SENTINEL_RGB_BIS.tif windows:  84% 6120/7286 [01:36<00:15, 76.14it/s]/usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
#
# 2017-NOV-MOSAIC-SENTINEL_RGB_BIS.tif windows:  84% 6131/7286 [01:36<00:13, 85.35it/s]/usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
#
# 2017-NOV-MOSAIC-SENTINEL_RGB_BIS.tif windows:  84% 6140/7286 [01:36<00:13, 84.30it/s]/usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# ...
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
#
# 2017-NOV-MOSAIC-SENTINEL_RGB_BIS.tif windows: 100% 7262/7286 [01:50<00:00, 64.78it/s]/usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
#
# 2017-NOV-MOSAIC-SENTINEL_RGB_BIS.tif windows: 100% 7273/7286 [01:51<00:00, 74.80it/s]/usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
#
# 2017-NOV-MOSAIC-SENTINEL_RGB_BIS.tif windows: 100% 7281/7286 [01:51<00:00, 75.55it/s]/usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 15 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# /usr/local/lib/python3.8/dist-packages/rasterio/features.py:324: ShapeSkipWarning: Invalid or empty shape {'type': 'Polygon', 'coordinates': ()} at index 24 will not be rasterized.
#   warnings.warn('Invalid or empty shape {} at index {} will not be rasterized.'.format(geom, index), ShapeSkipWarning)
# 2017-NOV-MOSAIC-SENTINEL_RGB_BIS.tif windows: 100% 7286/7286 [01:51<00:00, 65.52it/s]
# Rasters: 100% 1/1 [01:59<00:00, 119.87s/it]

# %%
# %cd /tmp
# Out:
# /tmp

# %%
!7z a CHIPS.zip CHIPS/
# Out:
# 7-Zip [64] 16.02 : Copyright (c) 1999-2016 Igor Pavlov : 2016-05-21
# p7zip Version 16.02 (locale=en_US.UTF-8,Utf16=on,HugeFiles=on,64 bits,2 CPUs Intel(R) Xeon(R) CPU @ 2.20GHz (406F0),ASM,AES-NI)
#
# Scanning the drive:
# 3 folders, 28418 files, 4838717820 bytes (4615 MiB)
#
# Creating archive: CHIPS.zip
#
# Items to compress: 28421
#
#  99% 28415 + CHIPS/images/SEP-2015-AMBA-SENTINEL_RGB_51_73.tif
# Files read from disk: 28418
# Archive size: 1714271425 bytes (1635 MiB)
# Everything is Ok

# %%
# !cp CHIPS.zip /content/drive/MyDrive/Basurales/AMBA/labels/

# %%
# !ls -la /content/drive/MyDrive/Basurales/AMBA/labels/
# Out:
# total 1674102
# drwx------ 21 root root       4096 Oct 13 23:08 ANOTACIONES
# drwx------  2 root root       4096 Jan 13 14:29 AREA_DE_INTERES
# -rw-------  1 root root 1714271425 Jan 16 19:28 CHIPS.zip
# -rw-------  1 root root        187 Jan 13 14:21 info.gdoc
